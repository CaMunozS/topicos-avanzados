# %% [markdown]
# # Tópicos Avanzados — Exploración inicial
#
# Completa el título específico, integrantes, fecha y objetivo de la tarea.

# %% [markdown]
# ## 1. Problema y objetivos
#
# - **Problema:** por definir.
# - **Objetivo general:** por definir.
# - **Objetivos específicos:** por definir.

# %%
from pathlib import Path
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROJECT_ROOT

# %% [markdown]
# ## 2. Carga y validación de datos

# %%
# Ejemplo:
# data_path = PROJECT_ROOT / 'data' / 'raw' / 'datos.csv'
# df = pd.read_csv(data_path)
# df.info()

# %% [markdown]
# ## 3. Análisis o modelamiento
#
# Documenta decisiones, supuestos, parámetros y métricas.

# %% [markdown]
# ## 4. Resultados y conclusiones
#
# Resume hallazgos, limitaciones y próximos pasos.
